# %%
import pandas as pd
df = pd.read_csv("datathon data/stock_data.csv")
df.columns
# Out:
# Index(['Date', 'Ticker_Symbol', 'Close_lag_1', 'Close_logreturn', 'Year',
#        'Type', 'Type_Clean', 'Unit', 'Geography', 'Gas_Price', 'Month',
#        'Refining', 'Distribution_and_Marketing', 'Taxes', 'Crude_Oil',
#        'Brent_Price', 'Gas_Price_logreturn', 'Gas_Price_pct',
#        'Brent_Price_logreturn', 'Brent_Price_pct', 'Refining_logreturn',
#        'Refining_pct', 'Taxes_logreturn', 'Taxes_pct',
#        'Distribution_and_Marketing_logreturn',
#        'Distribution_and_Marketing_pct', 'Crude_Oil_logreturn',
#        'Crude_Oil_pct', 'Gas_Price_lag_1'],
#       dtype='object')

# %% [markdown]
# ### Train XGBoost and Random Forest for each stock

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

# Assume `df` is your full DataFrame with a 'Ticker_Symbol' column
label_col = 'Close_logreturn'
feature_cols = [
    col for col in df.columns
    if (
        col == 'Close_lag_1'
        or col == 'Stock_Number'
        or '_logreturn' in col
    )
    and col != label_col
]

print(feature_cols)

# Prepare a dict to hold per‐ticker results
results = {}

for symbol in df['Ticker_Symbol'].unique():
    # print(f"Processing {symbol}...")
    
    # 1) Subset the DataFrame to this ticker
    sub = df[df['Ticker_Symbol'] == symbol].copy()
    
    # 2) Extract X and y
    X = sub[feature_cols]
    y = sub[label_col]

    # 3) Standardize
    scaler = StandardScaler()
    X_scaled = pd.DataFrame(
        scaler.fit_transform(X),
        index=X.index,
        columns=X.columns
    )
    y_scaled = pd.Series(
        scaler.fit_transform(y.values.reshape(-1, 1)).ravel(),
        index=y.index,
        name=y.name
    )

    # print(X)
    # print(y)
    
    # 4) Train/test split
    X_train, X_test, y_train, y_test = train_test_split(
        X_scaled, y_scaled, test_size=0.2, random_state=42
    )
    
    # 5) Fit model
    model = XGBRegressor(random_state=42)
    model.fit(X_train, y_train)
    
    # 6) Predict & evaluate
    y_pred_test = model.predict(X_test)
    y_pred_train = model.predict(X_train)
    mse_test = mean_squared_error(y_test, y_pred_test)
    mse_train = mean_squared_error(y_train, y_pred_train)
    
    # 7) Feature importances
    feat_imp = pd.DataFrame({
        'feature': X.columns,
        'importance': model.feature_importances_
    }).sort_values('importance', ascending=False)
    
    # 8) Store results
    results[symbol] = {
        'model': model,
        'mse_train': mse_train,
        'mse_test': mse_test,
        'feature_importances': feat_imp
    }

print(f"Processing {symbol}...")

# Accessing results for e.g. ticker "HAL":
print("HAL train MSE:", results['HAL']['mse_train'])
print("HAL test MSE:",  results['HAL']['mse_test'])
print("HAL top features:\n", results['HAL']['feature_importances'].head())
# Out:
# ['Close_lag_1', 'Gas_Price_logreturn', 'Brent_Price_logreturn', 'Refining_logreturn', 'Taxes_logreturn', 'Distribution_and_Marketing_logreturn', 'Crude_Oil_logreturn']
# Processing SPY...
# HAL train MSE: 0.005361292484141061
# HAL test MSE: 1.1560005676426819
# HAL top features:
#                                  feature  importance
# 4                       Taxes_logreturn    0.182865
# 2                 Brent_Price_logreturn    0.177427
# 6                   Crude_Oil_logreturn    0.168130
# 5  Distribution_and_Marketing_logreturn    0.142589
# 3                    Refining_logreturn    0.134166

# %%
from matplotlib import pyplot as plt
import seaborn as sns
for symbol in df['Ticker_Symbol'].unique():
    print(f"{symbol} train MSE:", results[symbol]['mse_train'])
    print(f"{symbol} test MSE:",  results[symbol]['mse_test'])
    
    feat_importance = results[symbol]['feature_importances']
    feat_importance['feature'] = feat_importance['feature'].str.replace('_logreturn', '')
    feat_importance['feature'] = feat_importance['feature'].str.replace('Close_lag_1', 'Close')
    feat_importance['feature'] = feat_importance['feature'].str.replace('Stock_Number', 'Stock Number')
    feat_importance['feature'] = feat_importance['feature'].str.replace('logreturn', 'Log Return')

    # Plotting
    plt.figure(figsize=(10, 6))
    sns.barplot(x='importance', y='feature', data=feat_importance)
    plt.title(f"Feature Importance for {symbol}")
    plt.tight_layout()
    plt.show()
# Out:
# HAL train MSE: 0.005361292484141061
# HAL test MSE: 1.1560005676426819
# FANG train MSE: 0.00037410157686594423
# FANG test MSE: 1.5724136040295413
# E train MSE: 0.001533192880712307
# E test MSE: 1.7449397329887795
# EXC train MSE: 0.003436988175980991
# EXC test MSE: 1.3051222244149105
# HES train MSE: 0.0049113076522262124
# HES test MSE: 1.2813910152469756
# BKR train MSE: 8.008448452438531e-06
# BKR test MSE: 1.6811531146433674
# BPT train MSE: 0.004279390275152701
# BPT test MSE: 1.321593843344838
# VLO train MSE: 0.00569439276603253
# VLO test MSE: 1.3224507280843238
# CVX train MSE: 0.0035879470868504875
# CVX test MSE: 1.2505711677877853
# OXY train MSE: 0.004878131107109742
# OXY test MSE: 1.380457783469558
# KMI train MSE: 0.00037608913264971854
# KMI test MSE: 1.3061404755076802
# PSX train MSE: 0.0002640511122197078
# PSX test MSE: 1.5928330084397564
# NOV train MSE: 0.005062138740902266
# NOV test MSE: 1.3759902566017932
# CHK train MSE: 9.912626699236421e-07
# CHK test MSE: 1.334972416592244
# MPC train MSE: 0.000425071277166473
# MPC test MSE: 1.4242234588813594
# DVN train MSE: 0.0031511317126225826
# DVN test MSE: 0.8728486296737211
# COP train MSE: 0.0049091163852343035
# COP test MSE: 1.3084845915118664
# EPD train MSE: 0.005473433153439808
# EPD test MSE: 1.1711707296864002
# BP train MSE: 0.004964773508640945
# BP test MSE: 1.2316006094810084
# XOM train MSE: 0.005364468067599622
# XOM test MSE: 1.3516939734790805
# EOG train MSE: 0.003697148930616688
# EOG test MSE: 2.945832350723622
# CEO train MSE: 0.004375969022249148
# CEO test MSE: 1.2914374045273733
# SLB train MSE: 0.004630634603085432
# SLB test MSE: 1.4119370356976026
# WMB train MSE: 0.0035996698690162754
# WMB test MSE: 1.9824676634932636
# ONEQ train MSE: 0.00350749493845763
# ONEQ test MSE: 1.1679960141992611
# DIA train MSE: 0.004899412097186416
# DIA test MSE: 1.4543695836633799
# VOO train MSE: 0.0009009328341709954
# VOO test MSE: 1.0675289036430138
# SPY train MSE: 0.005628223817455484
# SPY test MSE: 1.3757818336065257

# %%
# 1. Gather all unique features
features = results[next(iter(results))]['feature_importances']['feature'].tolist()

# 2. Initialize an empty DataFrame
imp_matrix = pd.DataFrame(
    index=results.keys(),
    columns=features,
    data=0.0
)

# 3. Fill in importances
for symbol, res in results.items():
    fi = res['feature_importances']
    imp_matrix.loc[symbol, fi['feature']] = fi['importance'].values

imp_matrix
# Out:
#          Taxes  Brent_Price  Crude_Oil  Distribution_and_Marketing  Refining  \
# HAL   0.182865     0.177427   0.168130                    0.142589  0.134166
# FANG  0.319329     0.140697   0.082138                    0.135973  0.151949
# E     0.108661     0.407845   0.045943                    0.058423  0.063328
# EXC   0.109476     0.112071   0.121610                    0.186337  0.203111
# HES   0.200313     0.143010   0.119577                    0.150048  0.179267
# BKR   0.330216     0.130024   0.132274                    0.116110  0.116849
# BPT   0.165029     0.119918   0.216991                    0.127422  0.141821
# VLO   0.159396     0.134328   0.160219                    0.151358  0.157764
# CVX   0.268865     0.104951   0.149720                    0.134080  0.164917
# OXY   0.137136     0.148452   0.150940                    0.183924  0.143555
# KMI   0.147655     0.170791   0.184529                    0.158349  0.090457
# PSX   0.181659     0.184366   0.151089                    0.097971  0.181136
# NOV   0.162570     0.119451   0.167811                    0.153549  0.196835
# CHK   0.124681     0.171138   0.244887                    0.129948  0.159768
# MPC   0.118929     0.173258   0.203973                    0.141643  0.119566
# DVN   0.116957     0.230463   0.115579                    0.110289  0.195493
# COP   0.131078     0.211830   0.167292                    0.131524  0.125537
# EPD   0.168819     0.144817   0.136311                    0.164708  0.166333
# BP    0.221418     0.130455   0.160392                    0.139110  0.157654
# XOM   0.168393     0.143071   0.150101                    0.156780  0.173532
# EOG   0.180823     0.155232   0.162066                    0.169204  0.139113
# CEO   0.195052     0.119485   0.151788                    0.125354  0.205043
# SLB   0.157414     0.144041   0.183381                    0.158019  0.154426
# WMB   0.135871     0.163384   0.162153                    0.142084  0.123331
# ONEQ  0.155746     0.151025   0.178961                    0.124926  0.210302
# DIA   0.156102     0.161111   0.100459                    0.138363  0.252032
# VOO   0.272771     0.118588   0.163287                    0.111545  0.139602
# SPY   0.159210     0.162823   0.138339                    0.144899  0.208130
#
#          Close  Gas_Price
# HAL   0.103065   0.091757
# FANG  0.067629   0.102285
# E     0.249673   0.066128
# EXC   0.079059   0.188336
# HES   0.099407   0.108378
# BKR   0.072803   0.101723
# BPT   0.119526   0.109292
# VLO   0.105112   0.131823
# CVX   0.091891   0.085577
# OXY   0.121061   0.114934
# KMI   0.093892   0.154327
# PSX   0.082916   0.120862
# NOV   0.087026   0.112759
# CHK   0.052354   0.117224
# MPC   0.110861   0.131769
# DVN   0.137757   0.093463
# COP   0.106101   0.126638
# EPD   0.098290   0.120721
# BP    0.088580   0.102390
# XOM   0.094996   0.113125
# EOG   0.095650   0.097912
# CEO   0.077721   0.125558
# SLB   0.095916   0.106803
# WMB   0.169328   0.103849
# ONEQ  0.079960   0.099081
# DIA   0.098264   0.093669
# VOO   0.115824   0.078382
# SPY   0.092880   0.093720

# %%
import pandas as pd

types_df = pd.read_excel("datathon data/stock_descriptions_class.xlsx")

# Save as CSV
types_df.to_csv("datathon data/stock_descriptions_class.csv", index=False)
types_df.rename(columns={'Symbol': 'Ticker_Symbol'}, inplace=True)
types_df
# Out:
#    Ticker_Symbol     AssetType  \
# 0            BKR  Common Stock
# 1             BP  Common Stock
# 2            BPT  Common Stock
# 3            CEO  Common Stock
# 4            CHK  Common Stock
# 5            COP  Common Stock
# 6            CVX  Common Stock
# 7            DVN  Common Stock
# 8              E  Common Stock
# 9            EOG  Common Stock
# 10           EPD  Common Stock
# 11           EXC  Common Stock
# 12          FANG  Common Stock
# 13           HAL  Common Stock
# 14           HES  Common Stock
# 15           KMI  Common Stock
# 16           MPC  Common Stock
# 17           NOV  Common Stock
# 18           OXY  Common Stock
# 19           PSX  Common Stock
# 20           SLB  Common Stock
# 21           VLO  Common Stock
# 22           WMB  Common Stock
# 23           XOM  Common Stock
# 24           DIA           ETF
# 25          ONEQ           ETF
# 26           SPY           ETF
# 27           VOO           ETF
# 28           NaN           NaN
# 29           NaN           NaN
# 30           NaN      upstream
# 31           NaN    downstream
# 32           NaN     midstream
# 33           NaN    Integrated
#
#                                                  Name  \
# 0                                Baker Hughes Company
# 1                                          BP PLC ADR
# 2                        BP Prudhoe Bay Royalty Trust
# 3                                       CNOOC Limited
# 4                       Chesapeake Energy Corporation
# 5                                      ConocoPhillips
# 6                                        Chevron Corp
# 7                            Devon Energy Corporation
# 8                                           Eni S.p.A
# 9                                   EOG Resources Inc
# 10                  Enterprise Products Partners L.P.
# 11                                 Exelon Corporation
# 12                           Diamondback Energy, Inc.
# 13                                Halliburton Company
# 14                                   Hess Corporation
# 15                                  Kinder Morgan Inc
# 16               Marathon Petroleum Corporation (MPC)
# 17                                           NOV Inc.
# 18                   Occidental Petroleum Corporation
# 19                                        Phillips 66
# 20                                    Schlumberger NV
# 21                          Valero Energy Corporation
# 22                             Williams Companies Inc
# 23                                   Exxon Mobil Corp
# 24        SPDR Dow Jones Industrial Average ETF Trust
# 25                Fidelity Nasdaq Composite Index ETF
# 26                       SPDR S&P 500 ETF Trust (SPY)
# 27                      Vanguard 500 Index Fund (VOO)
# 28                                                NaN
# 29                                                NaN
# 30  exploration & production: focus on locating an...
# 31  refining, distribution, selling finished produ...
# 32                  transportation and storage of oil
# 33                                                NaN
#
#                                           Description  \
# 0   Baker Hughes Company provides a portfolio of t...
# 1   BP plc participates in the energy business glo...
# 2   BP Prudhoe Bay Royalty Trust is a grantor trus...
# 3   CNOOC Limited operates exploration and product...
# 4   Chesapeake Energy Corporation, an independent ...
# 5   ConocoPhillips is an American multinational co...
# 6   Chevron Corporation is an American multination...
# 7   Devon Energy Corporation is an American energy...
# 8   Eni S.p.A. operates as an integrated energy co...
# 9   EOG Resources, Inc. is an American energy comp...
# 10  Enterprise Products Partners L.P. provides mid...
# 11  Exelon Corporation is an American Fortune 100 ...
# 12  Diamondback Energy, Inc., an independent oil a...
# 13  Halliburton Company is an American multination...
# 14  Hess Corporation (formerly Amerada Hess Corpor...
# 15  Kinder Morgan, Inc. is one of the largest ener...
# 16  Marathon Petroleum Corporation, together with ...
# 17  NOV Inc. is an American multinational corporat...
# 18  Occidental Petroleum Corporation is an America...
# 19  The Phillips 66 Company is an American multina...
# 20  Schlumberger Limited is an oilfield services c...
# 21  Valero Energy Corporation is a Fortune 500 int...
# 22  The Williams Companies, Inc., is an American e...
# 23  Exxon Mobil Corporation, stylized as ExxonMobi...
# 24  The DIA stock price tracks the performance of ...
# 25  The ONEQ stock price tracks the performance of...
# 26  The SPY stock price tracks the performance of ...
# 27  The VOO stock price tracks the performance of ...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
#
#                      Sector                               Industry  \
# 0   ENERGY & TRANSPORTATION         OIL & GAS EQUIPMENT & SERVICES
# 1   ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 2                TECHNOLOGY                                GENERAL
# 3   ENERGY & TRANSPORTATION         OIL & GAS EQUIPMENT & SERVICES
# 4   ENERGY & TRANSPORTATION         OIL & GAS EQUIPMENT & SERVICES
# 5   ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 6   ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 7   ENERGY & TRANSPORTATION          CRUDE PETROLEUM & NATURAL GAS
# 8   ENERGY & TRANSPORTATION                   OIL & GAS INTEGRATED
# 9   ENERGY & TRANSPORTATION          CRUDE PETROLEUM & NATURAL GAS
# 10  ENERGY & TRANSPORTATION                    OIL & GAS MIDSTREAM
# 11  ENERGY & TRANSPORTATION     ELECTRIC & OTHER SERVICES COMBINED
# 12  ENERGY & TRANSPORTATION                          OIL & GAS E&P
# 13  ENERGY & TRANSPORTATION          OIL & GAS FIELD SERVICES, NEC
# 14  ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 15  ENERGY & TRANSPORTATION               NATURAL GAS TRANSMISSION
# 16  ENERGY & TRANSPORTATION         OIL & GAS REFINING & MARKETING
# 17               TECHNOLOGY  OIL & GAS FIELD MACHINERY & EQUIPMENT
# 18  ENERGY & TRANSPORTATION          CRUDE PETROLEUM & NATURAL GAS
# 19  ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 20  ENERGY & TRANSPORTATION          OIL & GAS FIELD SERVICES, NEC
# 21  ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 22  ENERGY & TRANSPORTATION               NATURAL GAS TRANSMISSION
# 23  ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 24                 MULTIPLE                               MULTIPLE
# 25                 MULTIPLE                               MULTIPLE
# 26                 MULTIPLE                               MULTIPLE
# 27                 MULTIPLE                               MULTIPLE
# 28                      NaN                                    NaN
# 29                      NaN                                    NaN
# 30                      NaN                                    NaN
# 31                      NaN                                    NaN
# 32                      NaN                                    NaN
# 33                      NaN                                    NaN
#
#           chain
# 0     upstream*
# 1   downstream*
# 2      upstream
# 3      upstream
# 4      upstream
# 5      upstream
# 6    integrated
# 7      upstream
# 8    integrated
# 9      upstream
# 10    midstream
# 11   downstream
# 12     upstream
# 13     upstream
# 14     upstream
# 15    midstream
# 16   downstream
# 17     upstream
# 18     upstream
# 19   downstream
# 20     upstream
# 21   downstream
# 22    midstream
# 23   integrated
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.metrics import silhouette_score

# 1) Create 2D embedding via PCA for visualization
pca = PCA(n_components=2, random_state=42)
coords = pca.fit_transform(imp_matrix)
emb_df = pd.DataFrame(coords, index=imp_matrix.index, columns=['PC1', 'PC2'])
emb_df['Ticker_Symbol'] = emb_df.index
emb_df
# Out:
#            PC1       PC2 Ticker_Symbol
# HAL   0.013108  0.011775           HAL
# FANG -0.078655  0.136837          FANG
# E     0.324600  0.105214             E
# EXC  -0.030827 -0.093467           EXC
# HES  -0.024989  0.021415           HES
# BKR  -0.086601  0.137491           BKR
# BPT  -0.021910 -0.032491           BPT
# VLO  -0.014063 -0.028872           VLO
# CVX  -0.084448  0.068546           CVX
# OXY   0.013494 -0.038574           OXY
# KMI   0.021186 -0.034054           KMI
# PSX   0.007789  0.008953           PSX
# NOV  -0.042975 -0.039197           NOV
# CHK  -0.004710 -0.080970           CHK
# MPC   0.037169 -0.058862           MPC
# DVN   0.095589 -0.012265           DVN
# COP   0.064148 -0.026015           COP
# EPD  -0.012917 -0.013424           EPD
# BP   -0.048098  0.027504            BP
# XOM  -0.017621 -0.017770           XOM
# EOG  -0.009591 -0.001591           EOG
# CEO  -0.056998 -0.006703           CEO
# SLB  -0.012780 -0.033507           SLB
# WMB   0.054798 -0.017618           WMB
# ONEQ -0.019830 -0.036812          ONEQ
# DIA  -0.002848 -0.013125           DIA
# VOO  -0.059103  0.084913           VOO
# SPY  -0.002917 -0.017332           SPY

# %%
# 2) Define clustering algorithms
k = 3
methods = {
    'KMeans':            KMeans(n_clusters=k, random_state=42,),
    'Agglomerative':     AgglomerativeClustering(n_clusters=k, linkage='ward'),
}

# 3) Run clustering, plot
for name, algo in methods.items():
    labels = algo.fit_predict(imp_matrix)
    emb_df[name] = labels

    # Silhouette score
    unique_labels = set(labels)
    if len(unique_labels) > 1 and -1 not in unique_labels:
        score = silhouette_score(imp_matrix, labels)
        print(f"{name} silhouette score: {score:.3f}")
    else:
        print(f"{name} produced {len(unique_labels)} clusters (including noise).")

    # Scatterplot in PCA space
    plt.figure(figsize=(6,5))
    sns.scatterplot(
        data=emb_df,
        x='PC1', y='PC2',
        hue=name,
        palette='tab10',
        s=100,
        legend='full'
    )
    plt.title(f"{name} Clustering (PCA Projection)")
    plt.legend(title='Cluster', bbox_to_anchor=(1.02, 1), loc='upper left')
    plt.tight_layout()
    plt.show()
# Out:
# KMeans silhouette score: 0.177
# Agglomerative silhouette score: 0.404

# %%
# 4) Heatmap of feature importances ordered by one cluster labeling
order = emb_df.sort_values('KMeans').index
plt.figure(figsize=(12,8))
sns.heatmap(
    imp_matrix.loc[order],
    cmap='viridis',
    cbar_kws={'label': 'Importance'},
    xticklabels=True,
    yticklabels=True
)
plt.xlabel("Feature")
plt.ylabel("Ticker (ordered by KMeans cluster)")
plt.title("Feature Importances Heatmap by Cluster")
plt.tight_layout()
plt.show()

# %%
for name in methods.keys():
    print(f"\n=== {name} cluster assignments ===")
    labels = emb_df[name]
    for cluster_label in sorted(labels.unique()):
        members = labels[labels == cluster_label].index.tolist()
        print(f"Cluster {cluster_label}: {members}")
# Out:
# === KMeans cluster assignments ===
# Cluster 0: ['HAL', 'BPT', 'VLO', 'OXY', 'KMI', 'CHK', 'MPC', 'DVN', 'COP', 'EOG', 'SLB', 'WMB']
# Cluster 1: ['FANG', 'EXC', 'HES', 'BKR', 'CVX', 'PSX', 'NOV', 'EPD', 'BP', 'XOM', 'CEO', 'ONEQ', 'DIA', 'VOO', 'SPY']
# Cluster 2: ['E']
#
# === Agglomerative cluster assignments ===
# Cluster 0: ['HAL', 'EXC', 'HES', 'BPT', 'VLO', 'OXY', 'KMI', 'PSX', 'NOV', 'CHK', 'MPC', 'DVN', 'COP', 'EPD', 'BP', 'XOM', 'EOG', 'CEO', 'SLB', 'WMB', 'ONEQ', 'DIA', 'SPY']
# Cluster 1: ['E']
# Cluster 2: ['FANG', 'BKR', 'CVX', 'VOO']

# %%
merged = pd.merge(emb_df, types_df, on='Ticker_Symbol', how='left')
merged
# Out:
#          PC1       PC2 Ticker_Symbol  KMeans  Agglomerative     AssetType  \
# 0   0.013108  0.011775           HAL       0              0  Common Stock
# 1  -0.078655  0.136837          FANG       1              2  Common Stock
# 2   0.324600  0.105214             E       2              1  Common Stock
# 3  -0.030827 -0.093467           EXC       1              0  Common Stock
# 4  -0.024989  0.021415           HES       1              0  Common Stock
# 5  -0.086601  0.137491           BKR       1              2  Common Stock
# 6  -0.021910 -0.032491           BPT       0              0  Common Stock
# 7  -0.014063 -0.028872           VLO       0              0  Common Stock
# 8  -0.084448  0.068546           CVX       1              2  Common Stock
# 9   0.013494 -0.038574           OXY       0              0  Common Stock
# 10  0.021186 -0.034054           KMI       0              0  Common Stock
# 11  0.007789  0.008953           PSX       1              0  Common Stock
# 12 -0.042975 -0.039197           NOV       1              0  Common Stock
# 13 -0.004710 -0.080970           CHK       0              0  Common Stock
# 14  0.037169 -0.058862           MPC       0              0  Common Stock
# 15  0.095589 -0.012265           DVN       0              0  Common Stock
# 16  0.064148 -0.026015           COP       0              0  Common Stock
# 17 -0.012917 -0.013424           EPD       1              0  Common Stock
# 18 -0.048098  0.027504            BP       1              0  Common Stock
# 19 -0.017621 -0.017770           XOM       1              0  Common Stock
# 20 -0.009591 -0.001591           EOG       0              0  Common Stock
# 21 -0.056998 -0.006703           CEO       1              0  Common Stock
# 22 -0.012780 -0.033507           SLB       0              0  Common Stock
# 23  0.054798 -0.017618           WMB       0              0  Common Stock
# 24 -0.019830 -0.036812          ONEQ       1              0           ETF
# 25 -0.002848 -0.013125           DIA       1              0           ETF
# 26 -0.059103  0.084913           VOO       1              2           ETF
# 27 -0.002917 -0.017332           SPY       1              0           ETF
#
#                                            Name  \
# 0                           Halliburton Company
# 1                      Diamondback Energy, Inc.
# 2                                     Eni S.p.A
# 3                            Exelon Corporation
# 4                              Hess Corporation
# 5                          Baker Hughes Company
# 6                  BP Prudhoe Bay Royalty Trust
# 7                     Valero Energy Corporation
# 8                                  Chevron Corp
# 9              Occidental Petroleum Corporation
# 10                            Kinder Morgan Inc
# 11                                  Phillips 66
# 12                                     NOV Inc.
# 13                Chesapeake Energy Corporation
# 14         Marathon Petroleum Corporation (MPC)
# 15                     Devon Energy Corporation
# 16                               ConocoPhillips
# 17            Enterprise Products Partners L.P.
# 18                                   BP PLC ADR
# 19                             Exxon Mobil Corp
# 20                            EOG Resources Inc
# 21                                CNOOC Limited
# 22                              Schlumberger NV
# 23                       Williams Companies Inc
# 24          Fidelity Nasdaq Composite Index ETF
# 25  SPDR Dow Jones Industrial Average ETF Trust
# 26                Vanguard 500 Index Fund (VOO)
# 27                 SPDR S&P 500 ETF Trust (SPY)
#
#                                           Description  \
# 0   Halliburton Company is an American multination...
# 1   Diamondback Energy, Inc., an independent oil a...
# 2   Eni S.p.A. operates as an integrated energy co...
# 3   Exelon Corporation is an American Fortune 100 ...
# 4   Hess Corporation (formerly Amerada Hess Corpor...
# 5   Baker Hughes Company provides a portfolio of t...
# 6   BP Prudhoe Bay Royalty Trust is a grantor trus...
# 7   Valero Energy Corporation is a Fortune 500 int...
# 8   Chevron Corporation is an American multination...
# 9   Occidental Petroleum Corporation is an America...
# 10  Kinder Morgan, Inc. is one of the largest ener...
# 11  The Phillips 66 Company is an American multina...
# 12  NOV Inc. is an American multinational corporat...
# 13  Chesapeake Energy Corporation, an independent ...
# 14  Marathon Petroleum Corporation, together with ...
# 15  Devon Energy Corporation is an American energy...
# 16  ConocoPhillips is an American multinational co...
# 17  Enterprise Products Partners L.P. provides mid...
# 18  BP plc participates in the energy business glo...
# 19  Exxon Mobil Corporation, stylized as ExxonMobi...
# 20  EOG Resources, Inc. is an American energy comp...
# 21  CNOOC Limited operates exploration and product...
# 22  Schlumberger Limited is an oilfield services c...
# 23  The Williams Companies, Inc., is an American e...
# 24  The ONEQ stock price tracks the performance of...
# 25  The DIA stock price tracks the performance of ...
# 26  The VOO stock price tracks the performance of ...
# 27  The SPY stock price tracks the performance of ...
#
#                      Sector                               Industry  \
# 0   ENERGY & TRANSPORTATION          OIL & GAS FIELD SERVICES, NEC
# 1   ENERGY & TRANSPORTATION                          OIL & GAS E&P
# 2   ENERGY & TRANSPORTATION                   OIL & GAS INTEGRATED
# 3   ENERGY & TRANSPORTATION     ELECTRIC & OTHER SERVICES COMBINED
# 4   ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 5   ENERGY & TRANSPORTATION         OIL & GAS EQUIPMENT & SERVICES
# 6                TECHNOLOGY                                GENERAL
# 7   ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 8   ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 9   ENERGY & TRANSPORTATION          CRUDE PETROLEUM & NATURAL GAS
# 10  ENERGY & TRANSPORTATION               NATURAL GAS TRANSMISSION
# 11  ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 12               TECHNOLOGY  OIL & GAS FIELD MACHINERY & EQUIPMENT
# 13  ENERGY & TRANSPORTATION         OIL & GAS EQUIPMENT & SERVICES
# 14  ENERGY & TRANSPORTATION         OIL & GAS REFINING & MARKETING
# 15  ENERGY & TRANSPORTATION          CRUDE PETROLEUM & NATURAL GAS
# 16  ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 17  ENERGY & TRANSPORTATION                    OIL & GAS MIDSTREAM
# 18  ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 19  ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 20  ENERGY & TRANSPORTATION          CRUDE PETROLEUM & NATURAL GAS
# 21  ENERGY & TRANSPORTATION         OIL & GAS EQUIPMENT & SERVICES
# 22  ENERGY & TRANSPORTATION          OIL & GAS FIELD SERVICES, NEC
# 23  ENERGY & TRANSPORTATION               NATURAL GAS TRANSMISSION
# 24                 MULTIPLE                               MULTIPLE
# 25                 MULTIPLE                               MULTIPLE
# 26                 MULTIPLE                               MULTIPLE
# 27                 MULTIPLE                               MULTIPLE
#
#           chain
# 0      upstream
# 1      upstream
# 2    integrated
# 3    downstream
# 4      upstream
# 5     upstream*
# 6      upstream
# 7    downstream
# 8    integrated
# 9      upstream
# 10    midstream
# 11   downstream
# 12     upstream
# 13     upstream
# 14   downstream
# 15     upstream
# 16     upstream
# 17    midstream
# 18  downstream*
# 19   integrated
# 20     upstream
# 21     upstream
# 22     upstream
# 23    midstream
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN

# %%
fig, ax = plt.subplots(figsize=(10, 8))

# 1) Draw an invisible scatter to set the axis limits correctly:
ax.scatter(merged['PC1'], merged['PC2'], s=0, alpha=0)

# 2) Then draw your text labels at the true coordinates
texts = []
for _, row in merged.iterrows():
    c = palette.get(row['chain'], (0.8,0.8,0.8))
    txt = ax.text(row['PC1'], row['PC2'], row['Ticker_Symbol'],
                  fontsize=9, color='black',
                  bbox=dict(facecolor=c, alpha=0.6, pad=1, edgecolor='none'))
    texts.append(txt)

# … rest unchanged …
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_title('PCA of Stocks, labeled by Ticker, colored by Chain')
ax.grid(True)

legend_handles = [
    Patch(facecolor=col, edgecolor='none', label=chain, alpha=0.6)
    for chain, col in palette.items()
]
ax.legend(handles=legend_handles, title='chain',
          bbox_to_anchor=(1.02,1), loc='upper left')

# nudge overlapping labels
adjust_text(texts, 
            only_move={'points':'y','texts':'y'},
            arrowprops=dict(arrowstyle='-', color='gray', alpha=0.5),
            ax=ax)

plt.tight_layout()
plt.show()
